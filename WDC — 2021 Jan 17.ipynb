# %%
# IPython -> Jupyter

print('Hello, world!')
# Out:
# Hello, world!

# %%
2 + 5
# Out:
# 7

# %%
print('a')    # enter == newline
print('b')    # enter == newline
print('c')    # shift+enter == execute and show results
# Out:
# a
# b
# c

# %%
2+2
3+3
4+4
# Out:
# 8

# %%
s = 'Hello, world!'

# %%
print(s)
# Out:
# Hello, world!

# %%
type(s)
# Out:
# str

# %%
s = 100

# %%
print(s)
# Out:
# 100

# %%
type(s)
# Out:
# int

# %% [markdown]
# 1. Data structures
# 2. Functions
# 3. Objects

# %%
x = 100

# %%
type(x)
# Out:
# int

# %%
name = input('Enter your name: ')
# Out:
# Enter your name: Reuven

# %%
name
# Out:
# 'Reuven'

# %%
x = 2

n = input('Enter a number: ')
# Out:
# Enter a number: 5

# %%
x * n
# Out:
# '55'

# %%
x = 6
x * n
# Out:
# '555555'

# %%
x + n
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-0dc0d2bbfbfa> in <module>
# ----> 1 x + n
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# shift + enter executes a cell

name = input('Enter your name: ')

if name == 'Reuven':
    print('Hi, boss!')
    print('Nice to see you again!')
else:
    print('Hello, ' + name + '.')
# Out:
# Enter your name: asdfa
# Hello, asdfa.

# %% [markdown]
# # Headline
#
# This is in Markdown. With *italics* and **boldface**.

# %%
# to get into Markdown mode, type M in command mode (click on left / pressing ESC)
# to get into Edit mode, type RET in command mode (or click in the cell)

# %% [markdown]
# # Data types: None

# %%
x = None

# %%
'' == None
# Out:
# False

# %%
0 == None
# Out:
# False

# %%
False == None
# Out:
# False

# %%
type(x)
# Out:
# NoneType

# %%
print(x)
# Out:
# None

# %%
x

# %% [markdown]
# # Data types: True and False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# Comparison operators:
#
# - `==`
# - `!=`
# - `<`
# - `<=`
# - `>`
# - `>=`

# %%
5 < 10
# Out:
# True

# %%
5 == 5
# Out:
# True

# %%
6 != 5
# Out:
# True

# %%
6 == 10
# Out:
# False

# %%
x = 10
y = 20

if x < y:
    print('x is less than y')
# Out:
# x is less than y

# %%
x = None

if x:
    print('True-ish')
else:
    print('False-ish')
# Out:
# False-ish

# %% [markdown]
# Everything in Python is `True` in a boolean context, except for:
#
# - `False`
# - `None`
# - 0
# - everything empty -- `''`, `[]`, `()`, `{}`

# %%
name = input('Enter your name: ')

if name:   # if the name is not the empty string...
    print('Hello, ' + name + '!')
else:      # if we *DID* get an empty string...
    print('You did not enter a name!')
# Out:
# Enter your name:
# You did not enter a name!

# %% [markdown]
# # Data structure: Numbers
#
# - `int`
# - `float`

# %%
x = 10
type(x)
# Out:
# int

# %%
x = 10
y = 3

# %%
x + y
# Out:
# 13

# %%
x - y
# Out:
# 7

# %%
x * y
# Out:
# 30

# %%
x / y   # truediv
# Out:
# 3.3333333333333335

# %%
x // y  # floordiv
# Out:
# 3

# %%
x ** y
# Out:
# 1000

# %%
x % y
# Out:
# 1

# %%
x
# Out:
# 10

# %%
x = x + 1
x
# Out:
# 11

# %%
# an easier way to add 1 to x
x += 1
x
# Out:
# 12

# %%
x++
# Out:
#   File "<ipython-input-57-0af4bb0eac37>", line 1
#     x++
#        ^
# SyntaxError: invalid syntax

# %%
x = 10
y = '20'

# %%
x + y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-cd60f97aa77f> in <module>
# ----> 1 x + y
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# to get an int from a string, use "int" as a function
x + int(y)
# Out:
# 30

# %%
# to get a string from anything, use "str" as a function
str(x) + y
# Out:
# '1020'

# %%
name = input('Enter your name: ')

if name == 'Reuven':
    print('Hi, boss!')
    print('Nice to see you')
elif name == 'whatever':
    print('That is not a name!')
else:
    print('Hello, ' + name + '.')
# Out:
# Enter your name: asdfafa
# Hello, asdfafa.

# %% [markdown]
# # Exercise: Guessing game
#
# 1. Make sure your Python 3 setup is working.
# 2. Generate a random integer from 0 through 100.
#
# ```python3
# import random
# n = random.randint(0, 100)
# ```
#
# 3. Print the number, so we don't have to guess too many times.
# 4. Print one of the following:
#     - You got it!
#     - Too low
#     - Too high

# %%
# to install Jupyter, type
# python -m pip install jupyter

# On the command line, you can then run: 
# jupyter notebook 
# python -m jupyter notebook

# %%
# python.org

# %%
x = 1234
x = x ** 20

# %%
x
# Out:
# 67035243914691711794360082394262505332216263021359359696306176

# %%
x = x ** 20
x
# Out:
# ...

# %%
x = x ** 20
x
# Out:
# ...

# %%
import random

number = random.randint(0, 100)
print(number)

guess = input('Guess the number: ')
guess = int(guess)

if guess == number:
    print('You got it!')
elif guess < number:
    print('Too low')
else:
    print('Too high')
# Out:
# 56
# Guess the number: 0
# Too low

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
x = 10
y = 10.0

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
x == y
# Out:
# True

# %%
x = 10
y = 3.0

x + y
# Out:
# 13.0

# %%
x - y
# Out:
# 7.0

# %%
float(x)
# Out:
# 10.0

# %%
float('10')
# Out:
# 10.0

# %%
int(123.456)
# Out:
# 123

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
x = 10+3j
y = 12-4j

# %%
x + y
# Out:
# (22-1j)

# %% [markdown]
# # Data type: string

# %%
python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-32886514c262> in <module>
# ----> 1 python
#
# NameError: name 'python' is not defined

# %%
python -m ensurepip
python -m pip install pip
python -m pip install jupyter

jupyter notebook
python -m jupyter notebook

# %%
s = 'abcd'
type(s)
# Out:
# str

# %%
s = "abcd"
type(s)
# Out:
# str

# %%
s
# Out:
# 'abcd'

# %%
s = 'He said, "Hello"'
print(s)
# Out:
# He said, "Hello"

# %%
s = "She's so nice"
print(s)
# Out:
# She's so nice

# %%
s = 'She\'s so nice'
print(s)
# Out:
# She's so nice

# %%
s
# Out:
# "She's so nice"

# %%
s = 'He said, "She\'s so nice"'
s
# Out:
# 'He said, "She\'s so nice"'

# %%
print(s)
# Out:
# He said, "She's so nice"

# %%
print('abcd
      efgh
      ijklmn')
# Out:
#   File "<ipython-input-109-b5e449074933>", line 1
#     print('abcd
#                ^
# SyntaxError: EOL while scanning string literal

# %%
s = 'abcd\nefgh\nijklmn'
print(s)
# Out:
# abcd
# efgh
# ijklmn

# %%
s
# Out:
# 'abcd\nefgh\nijklmn'

# %%
s = 'abcd'
len(s)
# Out:
# 4

# %%
s = 'abcd\n'
len(s)
# Out:
# 5

# %%
s = 'abcd\tefgh\tijkl'
print(s)
# Out:
# abcd	efgh	ijkl

# %%
len(s)
# Out:
# 14

# %%
# double a backslash to get one backslash character

s = 'abcd\\tefgh\\tijkl'
print(s)
# Out:
# abcd\tefgh\tijkl

# %%
path = 'c:\abcd\efgh\ijkl'
print(path)
# Out:
# c:bcd\efgh\ijkl

# %%
# \a == ASCII 7 -- alarm bell

# %%
path = 'c:\\abcd\\efgh\\ijkl'
print(path)
# Out:
# c:\abcd\efgh\ijkl

# %%
# double all of the backslashes with "raw string"
# use r  before the opening quote, and all backslashes are doubled

path = r'c:\abcd\efgh\ijkl'
print(path)
# Out:
# c:\abcd\efgh\ijkl

# %%
path
# Out:
# 'c:\\abcd\\efgh\\ijkl'

# %%
type(path)
# Out:
# str

# %%
s = 'abcdefghijklmnopqrstuvwxyz'
len(s)
# Out:
# 26

# %%
s[0]   # retrieve first character
# Out:
# 'a'

# %%
type(s[0])
# Out:
# str

# %%
s[1]
# Out:
# 'b'

# %%
s[2]
# Out:
# 'c'

# %%
s[25]
# Out:
# 'z'

# %%
i = 25
s[i]
# Out:
# 'z'

# %%
i = len(s) - 1
s[i]
# Out:
# 'z'

# %%
s[len(s)-1]
# Out:
# 'z'

# %%
s[-1]  # same as s[len(s)-1] -- we count from the right side!
# Out:
# 'z'

# %%
s[-2]
# Out:
# 'y'

# %%
s[-3]
# Out:
# 'x'

# %%
s[-4]
# Out:
# 'w'

# %%
s[-26]
# Out:
# 'a'

# %%
s[30]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-138-5ce8778ff461> in <module>
# ----> 1 s[30]
#
# IndexError: string index out of range

# %% [markdown]
# # Exercise: Grab a character
#
# 1. Ask the user to enter a string, and assign it to `s`.
# 2. Ask the user to enter an integer, and assign it to `i`.
# 3. If the number is < 0, say it's too low.
# 4. If the number is > the string length, say it's too high.
# 5. Print the character at that index.
#
# Example:
#
#     Enter a string: hello
#     Enter an index: 3
#     l
#
#     Enter a string: hello
#     Enter an index: 30
#     Too high
#
#     Enter a string: hello
#     Enter an index: -3
#     Too low

# %%
s = input('Enter a string: ')
i = input('Enter an index: ')
i = int(i)

if i < 0:
    print('Too low')
elif i >= len(s):     # off-by-one error
    print('Too high')
else:
    print(s[i])
# Out:
# Enter a string: hello
# Enter an index: 4
# o

# %%
s = input('Enter a string: ')
i = int(input('Enter an index: '))

if i <= 0:
    print('Too low')
    
elif i > len(s):
    print('Too high')
else:
    
    print('The letter in index ' + str(i) + ' is \"' + s[i-1] + '\"')
# Out:
# Enter a string: hello
# Enter an index: 0
# Too low

# %%
s
# Out:
# 'hello'

# %%
i
# Out:
# 0

# %%
print('The letter at index' + i + ' is ' + s[i] + '.')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-1183fd5a2466> in <module>
# ----> 1 print('The letter at index' + i + ' is ' + s[i] + '.')
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('The letter at index ' + str(i) + ' is ' + s[i] + '.')
# Out:
# The letter at index 0 is h.

# %%
# 3.6 -- f-strings started!
print(f'The letter at index {i} is {s[i]}.')
# Out:
# The letter at index 0 is h.

# %%
x = 10
y = 20

s = f'{x} + {y} = {x+y}'
s
# Out:
# '10 + 20 = 30'

# %%
type(s)
# Out:
# str

# %%
s = 'a+b=c'

s = f'{1+2}+{3+4}={3+7}'
s = '3+7=10'

# %%
# slice -- substring

# %%
s = 'abcdefghijklmnopqrstuvwxyz'

len(s)
# Out:
# 26

# %%
# slice syntax : s[start:end+1]

s[5:10]  # s, from index 5 until (not including) index 10
# Out:
# 'fghij'

# %%
s[10:20]
# Out:
# 'klmnopqrst'

# %%
s[:10]   # from the start until (not including) index 10
# Out:
# 'abcdefghij'

# %%
s[10:]  # from index 10 through the end
# Out:
# 'klmnopqrstuvwxyz'

# %%
# advanced slice syntax: s[start:end+1:step]

s[5:20:3]
# Out:
# 'filor'

# %%
s[::2]
# Out:
# 'acegikmoqsuwy'

# %%
s[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-160-2a138df92e52> in <module>
# ----> 1 s[100]
#
# IndexError: string index out of range

# %%
s[:100]
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
s[100:200]
# Out:
# ''

# %%
s
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
'a' in s
# Out:
# True
